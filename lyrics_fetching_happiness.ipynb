# %% [markdown]
# # Merging lyrics into the final dataset

# %%
import pandas as pd

# %%
df = pd.read_csv("data/master_dataset.csv")

# %%
fds = pd.read_csv("data/master_dataset.csv")

# %%
final_ds =pd.read_csv("data/final_dataset.csv")

# %%
df.head()
# Out:
#                title  tag     artist  year   views  \
# 0          Killa Cam  rap    Cam'ron  2004  173166
# 1         Can I Live  rap      JAY-Z  1996  468624
# 2  Forgive Me Father  rap   Fabolous  2003    4743
# 3       Down and Out  rap    Cam'ron  2004  144404
# 4             Fly In  rap  Lil Wayne  2005   78271
#
#                                        features  \
# 0                   {"Cam\\'ron","Opera Steve"}
# 1                                            {}
# 2                                            {}
# 3  {"Cam\\'ron","Kanye West","Syleena Johnson"}
# 4                                            {}
#
#                                               lyrics  id
# 0  [Chorus: Opera Steve & Cam'ron]\nKilla Cam, Ki...   1
# 1  [Produced by Irv Gotti]\n\n[Intro]\nYeah, hah,...   3
# 2  Maybe cause I'm eatin\nAnd these bastards fien...   4
# 3  [Produced by Kanye West and Brian Miller]\n\n[...   5
# 4  [Intro]\nSo they ask me\n"Young boy\nWhat you ...   6

# %%
fds.columns
# Out:
# Index(['source', 'domain', 'chart', 'region', 'country', 'continent', 'date',
#        'position', 'title', 'artist', 'url', 'scraped_at', 'city', 'track_id',
#        'album', 'energy', 'danceability', 'valence', 'tempo', 'loudness',
#        'acousticness', 'instrumentalness', 'speechiness', 'liveness'],
#       dtype='object')

# %%
fds.shape
# Out:
# (1425, 24)

# %%
df = df.drop(labels=["tag","year","views","id","features"], axis=1)

# %%
df.columns
# Out:
# Index(['title', 'artist', 'lyrics'], dtype='object')

# %%
merged = fds.merge(
    df,
    left_on=['title', 'artist'],
    right_on=['title', 'artist'],
    how='left'
)

# %%
merged.columns
# Out:
# Index(['source', 'domain', 'chart', 'region', 'country', 'continent', 'date',
#        'position', 'title', 'artist', 'url', 'scraped_at', 'city', 'track_id',
#        'album', 'energy', 'danceability', 'valence', 'tempo', 'loudness',
#        'acousticness', 'instrumentalness', 'speechiness', 'liveness',
#        'lyrics'],
#       dtype='object')

# %%
merged["lyrics"].isna().sum()
# Out:
# np.int64(1156)

# %%
lyrics_only = final_ds[['artist', 'title', 'lyrics']]
merged = merged.merge(
    lyrics_only,
    on=['artist', 'title'],
    how='left'
)

# %%
merged.drop(labels=["lyrics_x"], axis=1, inplace=True)
merged.rename(columns={"lyrics_y": "lyrics"}, inplace=True)

# %%
merged["lyrics"].isna().sum()
# Out:
# np.int64(822)

# %% [markdown]
# Half of the lyrics are still missing

# %%
import lyricsgenius
import time

genius = lyricsgenius.Genius("Dm_OS9PJm_1854rqdgXQX2BbTRjTb6pQ0kVScZUChIn8eoUvtzKKgjQPC88DuomX")
genius.verbose = False
genius.remove_section_headers = True

def get_lyrics(track_name, artist_name):
    try:
        time.sleep(1)  # avoid rate limit
        song = genius.search_song(track_name, artist_name)
        if song:
            return song.lyrics
        return None
    except Exception as e:
        print(f"--- Error fetching lyrics for {track_name}: {e}")
        return None

# %%
# apply only to missing lyrics
import re

missing_mask = merged['lyrics'].isna()

merged.loc[missing_mask, 'lyrics'] = merged.loc[missing_mask].apply(
    lambda row: get_lyrics(
        re.sub(r"\s*\(.*?\)", "", row['title']).strip('"').strip(),    # clean title
        row['artist'].split(' ')[0].strip()                          # first artist
    ),
    axis=1
)
# Out:
# --- Error fetching lyrics for Billie Jean: Request timed out:
# HTTPSConnectionPool(host='api.genius.com', port=443): Read timed out. (read timeout=5)
# 1424                                      Ghetto Gospel
#
#                              artist  ...  energy danceability  valence  \
# 326             Vince Guaraldi Trio  ...   0.386        0.497    0.695
# 604                     Rod Stewart  ...     NaN          NaN      NaN
# 605                           Jewel  ...     NaN          NaN      NaN
# 606   Percy Faith And His Orchestra  ...     NaN          NaN      NaN
# 633                      Elton John  ...     NaN          NaN      NaN
# ...                             ...  ...     ...          ...      ...
# 1408                      DJ 4kerty  ...     NaN          NaN      NaN
# 1412                   Xploitcomedy  ...     NaN          NaN      NaN
# 1415                           WRLD  ...     NaN          NaN      NaN
# 1422                         Wizkid  ...     NaN          NaN      NaN
# 1424                   Balloranking  ...     NaN          NaN      NaN
#
#        tempo loudness  acousticness  instrumentalness  speechiness  liveness  \
# 326   81.774  -14.177         0.784             0.927        0.038     0.167
# 604      NaN      NaN           NaN               NaN          NaN       NaN
# 605      NaN      NaN           NaN               NaN          NaN       NaN
# 606      NaN      NaN           NaN               NaN          NaN       NaN
# 633      NaN      NaN           NaN               NaN          NaN       NaN
# ...      ...      ...           ...               ...          ...       ...
# 1408     NaN      NaN           NaN               NaN          NaN       NaN
# 1412     NaN      NaN           NaN               NaN          NaN       NaN
# 1415     NaN      NaN           NaN               NaN          NaN       NaN
# 1422     NaN      NaN           NaN               NaN          NaN       NaN
# 1424     NaN      NaN           NaN               NaN          NaN       NaN
#
#       lyrics
# 326     None
# 604     None
# 605     None
# 606     None
# 633     None
# ...      ...
# 1408    None
# 1412    None
# 1415    None
# 1422    None
# 1424    None
#
# [176 rows x 25 columns]

# %%
merged.loc[merged["track_name"] == "うっせぇわ", "lyrics"] = get_lyrics("うっせぇわ", "")

# %% [markdown]
# 2 songs remaining: 1 is instrumental, the other's lyrics are not found by either of the methods, but it's findable on the web

# %%
merged.loc[merged["track_name"] == "海のリビング", "lyrics"] = "太陽が 咲いた\nうざったいくらい部屋ん中\n照らしてくれるじゃんか夏\n男、女 の性が\n暑さに反応 heartbeat\n\nグループLINEに送信 からの一瞬で返信\n目覚めのミルクティー いつもより遥か美味\nお気にのAir Force鏡でチェックして\nあいつの車置き場にダッシュして\n「お待たせ、いやお待たせし過ぎたね」\n“今日を皆んなで最高にする”このポテンシャル\n\n四人乗りの車で走らす\n湾岸線でこの曲流して\nホワイトムスクと 潮風が\n今日の思い出にスパイスを\n\n四人乗りの車で走らす\nそろそろ見えてくる場所は\nパッパッとお悩み 追っ払って\n笑顔を増やす海のリビング yeah\n\n「喉渇いたあ」「一旦コンビニよろ！」\nきんきんに冷えたコーラ\nファミチキ食べて気分豪華\n車のナンバー隠してはいチーズ\n\nうちらがファッション先取り 仲良しこよし\nエンジンかけてBluetooth 「え？え？」\nボリューム上げようか\n\n四人乗りの車で走らす\n湾岸線でこの曲流して\nホワイトムスクと潮風が\n今日の思い出にスパイスを\n\nお金も ないけど\n笑えりゃ無問題\nでもずっとは無いね\nこの気持ち無くさぬように yeah\n\n四人乗りの車で走らす\n海岸沿いでこの曲流して\nホワイトムスクと潮風が\n今日の思い出にスパイスを\n\n四人乗りの車で走らす\nそろそろ見えてくる場所は\n何年経っても 変わらずに\n笑顔を増やす海のリビング yeah"

# %%
merged[merged['lyrics'].isna()]
# Out:
#         source         domain    chart region        date  position  \
# 326  billboard  billboard.com  hot-100    NaN  2022-01-01        37
#
#                               title               artist  url  \
# 326  Linus And Lucy (Peanuts Theme)  Vince Guaraldi Trio  NaN
#
#                            scraped_at  ... speechiness acousticness  \
# 326  2025-11-22T15:10:20.303946+00:00  ...       0.038        0.784
#
#     instrumentalness  liveness  valence   tempo  time_signature  track_genre  \
# 326            0.927     0.167    0.695  81.774               4         jazz
#
#                   playlistname  lyrics
# 326  DW Emotion Exercise - Joy    None
#
# [1 rows x 31 columns]

# %% [markdown]
# # Adding a happiness score from lyrics using a prebuilt model

# %%
import re

def clean_lyrics(text):
    if pd.isna(text):
        return ""
    text = re.sub(r'\[.*?\]', '', text)
    text = text.replace('\n', ' ').replace('\r', ' ')
    text = re.sub(r'\s+', ' ', text)
    return text.strip()

# %%
d_lyrics = merged.copy()
d_lyrics['lyrics_clean'] = d_lyrics['lyrics'].apply(clean_lyrics)

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
import numpy as np

model_name = "nlptown/bert-base-multilingual-uncased-sentiment"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)
model.eval()
# Out:
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(105879, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSdpaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=5, bias=True)
# )

# %%
def get_happiness_chunks(text, max_tokens=512):
    words = text.split()
    chunk_size = 200 
    
    scores = []
    for i in range(0, len(words), chunk_size):
        chunk_text = " ".join(words[i:i+chunk_size])
        
        inputs = tokenizer(
            chunk_text,
            truncation=True,
            padding=True,
            max_length=max_tokens,
            return_tensors="pt"
        )
        
        with torch.no_grad():
            outputs = model(**inputs)
            logits = outputs.logits
            probs = torch.softmax(logits, dim=1).squeeze()
            # Convert logits to stars: 0 -> 1 star, 4 -> 5 stars
            star_score = sum((i+1)*probs[i].item() for i in range(len(probs)))
            # Normalize to 0-1
            happiness = (star_score - 1)/4
            scores.append(happiness)
    
    return np.mean(scores)

# %%
merged['happiness_from_lyrics'] = d_lyrics['lyrics_clean'].apply(get_happiness_chunks)
# Out:
# C:\Users\tomfo\AppData\Roaming\Python\Python313\site-packages\numpy\_core\fromnumeric.py:3904: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\tomfo\AppData\Roaming\Python\Python313\site-packages\numpy\_core\_methods.py:147: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
merged.head()
# Out:
#       source         domain    chart region  country  continent        date  \
# 0  billboard  billboard.com  hot-100    NaN      NaN        NaN  2023-01-07
# 1  billboard  billboard.com  hot-100    NaN      NaN        NaN  2022-07-02
# 2  billboard  billboard.com  hot-100    NaN      NaN        NaN  2022-07-02
# 3  billboard  billboard.com  hot-100    NaN      NaN        NaN  2023-01-07
# 4  billboard  billboard.com  hot-100    NaN      NaN        NaN  2022-07-02
#
#    position                title        artist  ...  danceability valence  \
# 0        39  Under The Influence   Chris Brown  ...         0.733   0.310
# 1        45               Efecto     Bad Bunny  ...         0.801   0.234
# 2        78      I Ain't Worried   OneRepublic  ...         0.704   0.825
# 3        31            As It Was  Harry Styles  ...         0.520   0.662
# 4         8        Glimpse Of Us          Joji  ...         0.440   0.268
#
#      tempo  loudness acousticness  instrumentalness  speechiness  liveness  \
# 0  116.992    -5.529       0.0635          0.000001       0.0427    0.1050
# 1   98.047    -8.797       0.1410          0.000017       0.0516    0.0639
# 2  139.994    -5.927       0.0826          0.000745       0.0475    0.0546
# 3  173.930    -5.338       0.3420          0.001010       0.0557    0.3110
# 4  169.914    -9.258       0.8910          0.000005       0.0531    0.1410
#
#                                               lyrics  happiness_from_lyrics
# 0  Kido, Kido\r\nK-K-Kido on the beat, better run...               0.395045
# 1  Yeah-yeah-yeah-yeah-yeah-yeah\r\nEh-eh-eh-eh\r...               0.317055
# 2  I don't know what you've been told\r\nBut time...               0.567530
# 3  [Intro]\r\nCome on, Harry, we wanna say goodni...               0.378523
# 4  She'd take the world off my shoulders\r\nIf it...               0.521973
#
# [5 rows x 26 columns]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.hist(merged['happiness_from_lyrics'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Song Happiness Scores')
plt.xlabel('Happiness Score')
plt.ylabel('Number of Songs')
plt.show()

# %%
merged.to_csv("data/dataset_lyrics.csv", index=False)

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Fetching more songs (adding less popular songs at the same time)

# %%
merged = df.merge(
    fds[['artist', 'title']],
    on=['artist', 'title'],
    how='left',
    indicator=True
)

ds_only = merged[merged['_merge'] == 'left_only'].drop(columns=['_merge'])

# %%
ds_sampled = ds_only.sample(n=1500, random_state=42)

# %%
ds_sampled.drop(columns=['year', "features", "id"], inplace=True)

# %%
ds_sampled.head(50)
# Out:
#                                                      title      tag  \
# 5371961                                        Baggy Pants      rap
# 4207706                                    The Five Senses     misc
# 5715947                                        Bright Idea     rock
# 3060784                                        Not Bout Us      rap
# 3094341                                                III      pop
# 2818337                                              Bugün      rap
# 4027304                                      Good Old Days      pop
# 986757                                            Whos Who      pop
# 2937485                                       Dance For Me      rap
# 1509804                             ALL MY LOVE IS FOR YOU      pop
# 2420014                            Piel Dorada Bonus Track      pop
# 1208527                                           Winnipeg      pop
# 5318426                                     Simple  Lovely      pop
# 3715177                        Lost Inside Your Heart Live      pop
# 270857   Something Out Of Nothing Cloud Nine Who Do You...      rap
# 4541284                                            Mais Um      rap
# 4861242                                         Passing By      pop
# 4066114                                     Back To School      rap
# 1716508                          Echoes of the Roman Ruins      pop
# 1344851                                      Once or Twice      pop
# 3303283                                      So Sorry Dear  country
# 1115463               Statues Amidst A Frozen Sand Of Time      pop
# 3204316                     Pooja what is  this behaviour?     misc
# 588586                                             Waiting     rock
# 4668055                                         Knifegirls      rap
# 3558186                                             Voices      rap
# 4652687                                      Lost in Space      pop
# 398970                                              Ikarus      rap
# 4793097                                    Sangre Malandra      rap
# 1727602                                      Korennonlento      pop
# 3480040                                       Honolulu Joe      pop
# 2399358                                             2 Door      rap
# 723213                            Round The Corner Sallies      pop
# 5528569                                         small talk      pop
# 3301274                                     Pride  Loyalty     rock
# 4270789                                      Any Open Door     rock
# 1810586                                           Harmonie      rap
# 353654                                          Ela é Sexy      rap
# 5117763                                            MAKUMBA      pop
# 790690                                     Might And Glory     rock
# 1745861                                 Pon Di Cocky - Raw      pop
# 5841565                              Demon 2021 - Remaster     rock
# 4273856                                              Maria      rap
# 772967                                  The Feeling Within      pop
# 3484732                                  Little Did I Know     rock
# 2982278                                         Skateboard      rap
# 2968529                                          Sad story      pop
# 5903889                                          Moonlight      rap
# 2459674                                       Dans le vrai      rap
# 1205232                                    Feliz en tu Día      pop
# 3204316  (Maybe it's from the gas...)\n(Yes, it is)\n[S...
# 588586   [Verse 1]\nRip apart like everything\nAnger me...
# 4668055  [Songtext zu „Knifegirls“ ft. Sin Davis]\n\n[H...
# 3558186  (Verse 1)\n\nSurrounded by these fucking voice...
# 4652687  [Instrumental]\n\nSupernova\n\n[Instrumental]\...
# 398970   [Part I:]\nVorbei ist es mit Feiern, größte Pa...
# 4793097  [Letra de "Sangre Malandra" ft. Cartel de Sant...
# 1727602  Muistatko hellepäivät?\nMuistatko vielä kesän ...
# 3480040  He stands six foot tall, he's bleach blonde co...
# 2399358  [Intro: Playboi Carti & LAMB$]\nCash Carti in ...
# 723213   Captain Dan:\nLet's go round the corner sally\...
# 5528569  How are the new tunes coming along?\nYeah, pre...
# 3301274  Not looking for a fight\nMy only goal is to ge...
# 4270789  [Verse 1]\nYou gotta move from here\nIf you wa...
# 1810586  [Refrain] (x4)\nFor all of y'all keepin' y'all...
# 353654   É Motirô...\n\n[Verso 1: Tio Fresh]\nDe onde v...
# 5117763  [Testo di "MAKUMBA"]\n\n[Intro: Noemi & Carl B...
# 790690   Rivers of fire at dead of night\nIn winter lyi...
# 1745861  Girl you are the one, whoa me baby\n\nGirl you...
# 5841565  [Verse 1]\nI'm letting you in, maybe you know\...
# 4273856  MARIA                                         ...
# 772967   Black Mark against my name\nFace to face it's ...
# 3484732  It started off as some friends who would often...
# 2982278  We all die\nWe all cry\nWe all lie\nWe all try...
# 2968529  Intro{On phone }\nHey baby(hello baby)\nAww my...
# 5903889  أنا الجذر أساس هالمواجع عم كافح وعم واصل بنفي ...
# 2459674  [Couplet 1]\nTenir un calibre vous fait bander...
# 1205232  Contra tu voluntad\nSe abre un párpado\nAl fin...

# %%
ds_sampled.to_csv("data/dataset_lyrics_additional.csv", index=False)

# %%
d_lyrics = ds_sampled.copy()
d_lyrics['lyrics_clean'] = d_lyrics['lyrics'].apply(clean_lyrics)

# %%
ds_sampled['happiness_from_lyrics'] = d_lyrics['lyrics_clean'].apply(get_happiness_chunks)
# Out:
# C:\Users\tomfo\AppData\Roaming\Python\Python313\site-packages\numpy\_core\fromnumeric.py:3904: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\tomfo\AppData\Roaming\Python\Python313\site-packages\numpy\_core\_methods.py:147: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.hist(ds_sampled['happiness_from_lyrics'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Song Happiness Scores')
plt.xlabel('Happiness Score')
plt.ylabel('Number of Songs')
plt.show()

# %%
finalds = pd.read_csv("data/final_dataset.csv")

# %%
finalds.head()
# Out:
#       source         domain    chart region        date  position  \
# 0  billboard  billboard.com  hot-100    NaN  2023-01-07        39
# 1  billboard  billboard.com  hot-100    NaN  2022-07-02        45
# 2  billboard  billboard.com  hot-100    NaN  2022-07-02        78
# 3  billboard  billboard.com  hot-100    NaN  2023-01-07        31
# 4  billboard  billboard.com  hot-100    NaN  2022-07-02         8
#
#                  title        artist  url                        scraped_at  \
# 0  Under The Influence   Chris Brown  NaN  2025-11-22T15:08:01.843069+00:00
# 1               Efecto     Bad Bunny  NaN  2025-11-22T15:11:28.361775+00:00
# 2      I Ain't Worried   OneRepublic  NaN  2025-11-22T15:11:28.361775+00:00
# 3            As It Was  Harry Styles  NaN  2025-11-22T15:08:01.843069+00:00
# 4        Glimpse Of Us          Joji  NaN  2025-11-22T15:11:28.361775+00:00
#
#    ... v_audio_norm a_audio_norm  \
# 0  ...     0.271389     0.555317
# 1  ...     0.221465     0.436702
# 2  ...     0.775399     0.652749
# 3  ...     0.564861     0.609852
# 4  ...     0.323758     0.352024
#
#                                               lyrics  lyrics_language  \
# 0  Kido, Kido\r\nK-K-Kido on the beat, better run...               en
# 1  Yeah-yeah-yeah-yeah-yeah-yeah\r\nEh-eh-eh-eh\r...               es
# 2  I don't know what you've been told\r\nBut time...               en
# 3  [Intro]\r\nCome on, Harry, we wanna say goodni...               en
# 4  She'd take the world off my shoulders\r\nIf it...               en
#
#    h_lyrics_raw  h_lyrics_01  h_lyrics_norm   h_track  catharsis_score  \
# 0      6.248293     0.656037       0.623342  0.482561         0.287343
# 1      6.020741     0.627593       0.502073  0.389830         0.266463
# 2      5.272329     0.534041       0.165029  0.409177         0.385659
# 3      5.939429     0.617429       0.457912  0.500691         0.304504
# 4      6.264151     0.658019       0.631414  0.508352         0.173072
#
#    happiness_from_lyrics
# 0               0.395045
# 1               0.317055
# 2               0.567530
# 3               0.378523
# 4               0.521973
#
# [5 rows x 42 columns]

# %%
df_merged = pd.concat([ds_sampled, finalds], ignore_index=True)

# %%
df_merged.columns
# Out:
# Index(['title', 'tag', 'artist', 'views', 'lyrics', 'happiness_from_lyrics',
#        'source', 'domain', 'chart', 'region', 'date', 'position', 'url',
#        'scraped_at', 'track_name', 'artists', 'album_name', 'popularity',
#        'duration_ms', 'explicit', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature', 'track_genre', 'playlistname',
#        'v_audio_raw', 'a_audio_raw', 'v_audio_norm', 'a_audio_norm',
#        'lyrics_language', 'h_lyrics_raw', 'h_lyrics_01', 'h_lyrics_norm',
#        'h_track', 'catharsis_score'],
#       dtype='object')

# %%
df_merged.to_csv("data/final_dataset_additional.csv", index=False)

# %% [markdown]
# -----

# %% [markdown]
# ## Only computing happinness from lyrics to a dataset

# %%
df = pd.read_csv("data/final.csv")

# %%
df['lyrics_clean'] = df['lyrics'].apply(clean_lyrics)

# %%
mask = df["happiness_from_lyrics"].isna()

# %%
df.loc[mask, "happiness_from_lyrics"] = (
    df.loc[mask, "lyrics_clean"]
      .apply(get_happiness_chunks)
)
# Out:
# C:\Users\tomfo\AppData\Roaming\Python\Python313\site-packages\numpy\_core\fromnumeric.py:3904: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\tomfo\AppData\Roaming\Python\Python313\site-packages\numpy\_core\_methods.py:147: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.hist(df['happiness_from_lyrics'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Song Happiness Scores')
plt.xlabel('Happiness Score')
plt.ylabel('Number of Songs')
plt.show()

# %%
df = df.drop(columns=['lyrics_clean'])

# %%
df.to_csv("data/final.csv")

# %%
df.columns
# Out:
# Index(['source', 'domain', 'chart', 'region', 'date', 'position', 'title',
#        'artist', 'scraped_at', 'track_name', 'artists', 'album_name',
#        'popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre', 'lyrics', 'lyrics_language', 'happiness_from_lyrics',
#        'track_id'],
#       dtype='object')
